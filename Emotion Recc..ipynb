# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in e:\important\lib\site-packages (0.0.79)
# Requirement already satisfied: tqdm>=4.30.0 in e:\important\lib\site-packages (from deepface) (4.64.1)
# Requirement already satisfied: tensorflow>=1.9.0 in e:\important\lib\site-packages (from deepface) (2.13.0)
# Requirement already satisfied: numpy>=1.14.0 in e:\important\lib\site-packages (from deepface) (1.23.5)
# Requirement already satisfied: Pillow>=5.2.0 in e:\important\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: pandas>=0.23.4 in e:\important\lib\site-packages (from deepface) (1.5.3)
# Requirement already satisfied: opencv-python>=4.5.5.64 in e:\important\lib\site-packages (from deepface) (4.8.0.76)
# Requirement already satisfied: gdown>=3.10.1 in e:\important\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: keras>=2.2.0 in e:\important\lib\site-packages (from deepface) (2.13.1)
# Requirement already satisfied: mtcnn>=0.1.0 in e:\important\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: gunicorn>=20.1.0 in e:\important\lib\site-packages (from deepface) (21.2.0)
# Requirement already satisfied: retina-face>=0.0.1 in e:\important\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: fire>=0.4.0 in e:\important\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: Flask>=1.1.2 in e:\important\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: termcolor in e:\important\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: six in e:\important\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: click>=8.0 in e:\important\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.4)
# Requirement already satisfied: Jinja2>=3.0 in e:\important\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in e:\important\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in e:\important\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: filelock in e:\important\lib\site-packages (from gdown>=3.10.1->deepface) (3.9.0)
# Requirement already satisfied: requests[socks] in e:\important\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in e:\important\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: packaging in e:\important\lib\site-packages (from gunicorn>=20.1.0->deepface) (22.0)
# Requirement already satisfied: pytz>=2020.1 in e:\important\lib\site-packages (from pandas>=0.23.4->deepface) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\important\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.13.0 in e:\important\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.57.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.24.2)
# Requirement already satisfied: absl-py>=1.0.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.4.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: setuptools in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (65.6.3)
# Requirement already satisfied: h5py>=2.9.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in e:\important\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: colorama in e:\important\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\important\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in e:\important\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: certifi>=2017.4.17 in e:\important\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\important\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\important\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\important\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in e:\important\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\important\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in e:\important\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in e:\important\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\important\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\important\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\important\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\important\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\important\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\important\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\important\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\important\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
import cv2

from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Can not open webcam")
    
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame,actions=['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (50,50),
                font,3,
                (0,0,255),
                2,
                cv2.LINE_4)
    cv2.imshow('Demo video',frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  6.90it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.22it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  8.53it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.09it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.95it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 23.09it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.36it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 25.42it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.10it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 22.23it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.51it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.88it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.52it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.60it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.74it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.73it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.22it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.28it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.92it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 22.24it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.73it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.03it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.40it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 21.36it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.90it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.95it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.99it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.61it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.76it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.78it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.42it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.68it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.15it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.32it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.71it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.03it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.91it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.21it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.54it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.82it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.62it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.39it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.25it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 22.78it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.50it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 21.01it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.86it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.88it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.33it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 25.03it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 21.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 28.44it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 23.60it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.76it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.40it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.79it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.37it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.93it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.48it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.39it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.58it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.55it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.32it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.19it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.99it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.47it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.03it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.07it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.29it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.53it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.97it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.29it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.89it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.39it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.70it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.75it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.95it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.31it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.57it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.80it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.30it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.41it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.68it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.50it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.75it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 24.73it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 24.73it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.60it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.16it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.87it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.84it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.86it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.59it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.70it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.31it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 24.99it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.37it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.96it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.71it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.59it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.45it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 22.80it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.83it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.44it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 25.51it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.37it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.74it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 21.71it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.63it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.64it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.85it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.09it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.49it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.99it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.78it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.74it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.14it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.28it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.30it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.98it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.46it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.49it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.42it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.11it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.03it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.36it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.20it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.47it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.74it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.05it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.89it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.61it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.83it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.58it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.64it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.64it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.29it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.59it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.37it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.60it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.89it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.50it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.07it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.97it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.86it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.47it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.84it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.76it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.45it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.91it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.55it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.11it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.67it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.84it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.36it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.15it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.70it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.72it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.88it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.68it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.32it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.41it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.61it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.46it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 21.56it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.79it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.06it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.46it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.55it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 11.61it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.16it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.44it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.74it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.18it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.26it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.48it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.45it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.56it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.46it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.71it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 12.65it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 while True:
#      15     ret,frame = cap.read()
# ---> 16     result = DeepFace.analyze(frame,actions=['emotion'])
#      18     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      20     faces = faceCascade.detectMultiScale(gray,1.1,4)
#
# File E:\Important\lib\site-packages\deepface\DeepFace.py:313, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     310 # ---------------------------------
#     311 resp_objects = []
# --> 313 img_objs = functions.extract_faces(
#     314     img=img_path,
#     315     target_size=(224, 224),
#     316     detector_backend=detector_backend,
#     317     grayscale=False,
#     318     enforce_detection=enforce_detection,
#     319     align=align,
#     320 )
#     322 for img_content, img_region, _ in img_objs:
#     323     if img_content.shape[0] > 0 and img_content.shape[1] > 0:
#
# File E:\Important\lib\site-packages\deepface\commons\functions.py:115, in extract_faces(img, target_size, detector_backend, grayscale, enforce_detection, align)
#     113 # in case of no face found
#     114 if len(face_objs) == 0 and enforce_detection is True:
# --> 115     raise ValueError(
#     116         "Face could not be detected. Please confirm that the picture is a face photo "
#     117         + "or consider to set enforce_detection param to False."
#     118     )
#     120 if len(face_objs) == 0 and enforce_detection is False:
#     121     face_objs = [(img, img_region, 0)]
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.

# %%
import cv2
img = cv2.imread('happy.jpg')

# %%
# Out:
#   File "C:\Users\DEEP KHOKHAR\AppData\Local\Temp\ipykernel_5168\3884529903.py", line 1
#     from tensorflow import keras.src
#                                 ^
# SyntaxError: invalid syntax

# %%
plt.imshow(img)

# %%
prediction = DeepFace.analyze(img)
# Out:
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Lenovo\.deepface\weights\age_model_weights.h5
#  56%|█████▌    | 301M/539M [01:25<01:00, 3.95MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 prediction = DeepFace.analyze(img)
#
# File E:\Important\lib\site-packages\deepface\DeepFace.py:303, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     300     models["emotion"] = build_model("Emotion")
#     302 if "age" in actions:
# --> 303     models["age"] = build_model("Age")
#     305 if "gender" in actions:
#     306     models["gender"] = build_model("Gender")
#
# File E:\Important\lib\site-packages\deepface\DeepFace.py:80, in build_model(model_name)
#      78 model = models.get(model_name)
#      79 if model:
# ---> 80     model = model()
#      81     model_obj[model_name] = model
#      82 else:
#
# File E:\Important\lib\site-packages\deepface\extendedmodels\Age.py:51, in loadModel(url)
#      48     print("age_model_weights.h5 will be downloaded...")
#      50     output = home + "/.deepface/weights/age_model_weights.h5"
# ---> 51     gdown.download(url, output, quiet=False)
#      53 age_model.load_weights(home + "/.deepface/weights/age_model_weights.h5")
#      55 return age_model
#
# File E:\Important\lib\site-packages\gdown\download.py:334, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format)
#     332     pbar = tqdm.tqdm(total=total, unit="B", unit_scale=True)
#     333 t_start = time.time()
# --> 334 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     335     f.write(chunk)
#     336     if not quiet:
#
# File E:\Important\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File E:\Important\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File E:\Important\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File E:\Important\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File E:\Important\lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File E:\Important\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File E:\Important\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File E:\Important\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
prediction

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
